# %%
from pathlib import Path
import utils

# %%
def get_path(type, split_name): 
    return Path(f"structures/{type}/{split_name}")

# %%
af_training_path = "dataset\\nrAF-Model-GO_train_sequences.fasta"
af_test_path = "dataset\\nrAF-Model-GO_test_sequences.fasta"
af_validation_path = "dataset\\nrAF-Model-GO_val_sequences.fasta"

pdb_training_path = "dataset\\nrPDB-GO_2019.06.18_train_sequences.fasta"
pdb_test_path = "dataset\\nrPDB-GO_2019.06.18_test_sequences.fasta"
pdb_validation_path = "dataset\\nrPDB-GO_2019.06.18_val_sequences.fasta"

af_paths = [af_training_path, af_test_path, af_validation_path]
pdb_paths = [pdb_training_path, pdb_test_path, pdb_validation_path]

# %%
pdb_training_save_dir = get_path("pdb", "pdb_test")
utils.download_multiple_structures_fast(pdb_test_path, pdb_training_save_dir, utils._download_one_pdb_structure)
# Out:
# Total unique structures: 3020
# Already present: 3020
# Need to download: 0
# ...
# Finished.
# Downloaded: 0
# Skipped existing: 3020
# Failed: 0
# {'downloaded': set(),
#  'skipped': {'6enu',
#   '3df0',
#   '6f41',
#   '1lv9',
#   '3d68',
#   '4o6z',
#   '1dxt',
#   '2yxv',
#   '2zj1',
#   '1sir',
#   '3eiq',
#   '5jqm',
#   '1mzb',
#   '5b8a',
#   '2qt9',
#   '5xql',
#   '3bts',
#   '1c9y',
#   '1nsk',
#   '5vy8',
#   '2wvd',
#   '4gh7',
#   '3o4f',
#   '3l6c',
#   '5w0c',
#   '6gpk',
#   '1o8t',
#   '6bcu',
#   '3cos',
#   '3gzd',
#   '4egc',
#   '5fpn',
#   '4rym',
#   '5h3o',
#   '3uc3',
#   '2a79',
#   '1h2t',
#   '1va6',
#   '5voz',
#   '3a9z',
#   '1w07',
#   '3vn9',
#   '1q1q',
#   '2a7s',
#   '2e30',
#   '4z9m',
#   '3fy7',
#   '1e1n',
#   '2yz2',
#   '1su3',
#   '2r46',
#   '5u9m',
#   '4dxa',
#   '5hzw',
#   '2b0u',
#   '6cpl',
#   '1uea',
#   '3q68',
#   '2wwr',
#   '5bv7',
#   '3u9s',
#   '5diz',
#   '1ct9',
#   '3qb5',
#   '5on6',
#   '6ndj',
#   '1fba',
#   '2wp9',
# ...

# %%
af_test_save_dir = get_path("af", "af_test")
utils.download_multiple_structures_fast(af_test_path, af_test_save_dir, utils._download_one_af_structure)
# Out:
# Total unique structures: 567
# Already present: 507
# Need to download: 60
# ...
# Finished.
# Downloaded: 60
# Skipped existing: 507
# Failed: 0
# {'downloaded': {'a0b9k4',
#   'a0qxd9',
#   'a1cgw7',
#   'a1zag4',
#   'a1zb86',
#   'a2afr3',
#   'a2bdr7',
#   'a2qbz0',
#   'a4rd35',
#   'a5pka5',
#   'a6qgc0',
#   'a6qnt4',
#   'a8abf5',
#   'a8mxk1',
#   'a8mz26',
#   'b9gag9',
#   'c7dzk3',
#   'd0z5n4',
#   'd3zb94',
#   'e9q7x7',
#   'e9q956',
#   'f4hxz1',
#   'f4jt76',
#   'f6qeu4',
#   'g5ebh0',
#   'g5ed00',
#   'g5ees6',
#   'k7na32',
#   'm0r2j8',
#   'o01789',
#   'q09739',
#   'q09746',
#   'q09844',
#   'q0zlh2',
#   'q10138',
#   'q10199',
#   'q10pi9',
#   'q12038',
#   'q12200',
#   'q12wl3',
#   'q13939',
#   'q149n8',
#   'q18891',
#   'q1e065',
#   'q1kpv0',
#   'q8cfe4',
#   'q8ixv7',
#   'q8izf0',
#   'q8lgn1',
#   'q8lps2',
#   'q8na31',
#   'q8nhp6',
#   'q8r4y4',
#   'q8s8n9',
#   'q8t7k0',
#   'q8ve09',
#   'q8wxd0',
#   'q91z67',
#   'q921g8',
#   'q922j3'},
# ...

# %%
af_train_save_dir = get_path("af", "af_train")
utils.download_multiple_structures_fast(af_training_path, af_train_save_dir, utils._download_one_af_structure)
# Out:
# Total unique structures: 38185
# Already present: 38152
# Need to download: 33
# ...
# Finished.
# Downloaded: 0
# Skipped existing: 38152
# Failed: 33
#
# Sample failures:
#   a0a060x6z0: HTTPSConnectionPool(host='alphafold.ebi.ac.uk', port=443): Max retries exceeded with url: /api/prediction/a0a060x6z0 (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1000)')))
#   a0a087x1c5: HTTPSConnectionPool(host='alphafold.ebi.ac.uk', port=443): Max retries exceeded with url: /api/prediction/a0a087x1c5 (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1000)')))
#   a0a0a1h8i4: HTTPSConnectionPool(host='alphafold.ebi.ac.uk', port=443): Max retries exceeded with url: /api/prediction/a0a0a1h8i4 (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1000)')))
# ...

# %%
af_validation_save_dir = get_path("af", "af_validation")
utils.download_multiple_structures_fast(af_validation_path, af_validation_save_dir, utils._download_one_af_structure)
# Out:
# Total unique structures: 4242
# Already present: 0
# Need to download: 4242
# ...
# Finished.
# Downloaded: 137
# Skipped existing: 0
# Failed: 4105
#
# Sample failures:
#   a0a044re18: HTTPSConnectionPool(host='alphafold.ebi.ac.uk', port=443): Max retries exceeded with url: /api/prediction/a0a044re18 (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1000)')))
#   a0a087wvf3: HTTPSConnectionPool(host='alphafold.ebi.ac.uk', port=443): Max retries exceeded with url: /api/prediction/a0a087wvf3 (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1000)')))
#   a0a0c5prw9: HTTPSConnectionPool(host='alphafold.ebi.ac.uk', port=443): Max retries exceeded with url: /api/prediction/a0a0c5prw9 (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1000)')))
# ...
